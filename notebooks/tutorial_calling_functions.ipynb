# %% [markdown]
# # Exploratory Analysis for ProtLatDyn
#
# Initial exploration of protein lattice dynamics

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

print(f"PyTorch version: {torch.__version__}")
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("Number of GPUs:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 3090
# Number of GPUs: 1

# %%
import torch

# %%
import os
import sys

# Move up one level to the 'my_project' directory
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to the system path so Python can find 'src'
if project_root not in sys.path:
    sys.path.append(project_root)

print(f"System path updated to include: {project_root}")
# Out:
# System path updated to include: /home/ldibari/ldibari/ProtLatDyn

# %%
# Import the function exposed by src/__init__.py
from src import format_name, calculate_age_in_months

# Test 1: Call the function
name_result = format_name("  jOhN ", " doe ")
print(f"Formatted Name: {name_result}")

# Test 2: Call the second function
months = calculate_age_in_months(30)
print(f"Age in months: {months}")
# Out:
# Formatted Name: John Doe
# Age in months: 360

# %%
from src.utils import torch

# %%
from src import compute_gibbs_probabilities
